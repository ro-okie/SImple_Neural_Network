# %% [markdown]
# <a href="https://colab.research.google.com/github/ro-okie/SImple_Neural_Network/blob/main/Simple_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
import torch.nn as nn

# %%
x = torch.tensor(([2,9], [1,5], [3,6]),dtype=torch.float)
y = torch.tensor(([92], [100], [89]),dtype = torch.float)
xtest = torch.tensor(([4, 8]), dtype = torch.float)

# %%
print(x.size())
print(y.size())
# Out:
# torch.Size([3, 2])
# torch.Size([3, 1])

# %%
X_max, _ = torch.max(x, 0)
xtest_max, _ = torch.max(xtest, 0)

x = torch.div(x, X_max)
xtest = torch.div(xtest, xtest_max)
y = y/100

# %%
class Neural_Network(nn.Module):
  def __init__(self):
    super(Neural_Network, self).__init__()
    
    #parameters:
    self.input_size = 2
    self.output_size = 1
    self.hidden_size = 3

    #weights initialization
    self.W1 = torch.randn(self.input_size, self.hidden_size)
    self.W2 = torch.randn(self.hidden_size, self.output_size)


  def forward(self, X):
    self.z = torch.matmul(X, self.W1) 
    self.z2 = self.sigmoid(self.z) 
    self.z3 = torch.matmul(self.z2, self.W2)
    o = self.sigmoid(self.z3) 
    return o

  def sigmoid(self, s):
        return 1 / (1 + torch.exp(-s))


  def sigmoidPrime(self, s):
        # derivative of sigmoid
        return s * (1 - s)
    
  def backward(self, X, y, o):
        self.o_error = y - o # error in output
        self.o_delta = self.o_error * self.sigmoidPrime(o) # derivative of sig to error
        self.z2_error = torch.matmul(self.o_delta, torch.t(self.W2))
        self.z2_delta = self.z2_error * self.sigmoidPrime(self.z2)
        self.W1 += torch.matmul(torch.t(X), self.z2_delta)
        self.W2 += torch.matmul(torch.t(self.z2), self.o_delta)

  def train(self, X, y):
        # forward + backward pass for training
        o = self.forward(X)
        self.backward(X, y, o)

  def saveWeights(self, model):
        # we will use the PyTorch internal storage functions
        torch.save(model, "NN")
        # you can reload model with all the weights and so forth with:
        # torch.load("NN")

  def predict(self):
        print ("Predicted data based on trained weights: ")
        print ("Input (scaled): \n" + str(xtest))
        print ("Output: \n" + str(self.forward(xtest)))

# %%
NN = Neural_Network()
for i in range(1000):
  print ("#" + str(i) + " Loss: " + str(torch.mean((y - NN(x))**2).detach().item()))
  NN.train(x,y)


NN.saveWeights(NN)
NN.predict()
# Out:
# #0 Loss: 0.18599171936511993
# #1 Loss: 0.13900919258594513
# #2 Loss: 0.10506954044103622
# #3 Loss: 0.08078256249427795
# #4 Loss: 0.06334216892719269
# #5 Loss: 0.050677668303251266
# #6 Loss: 0.04133904352784157
# #7 Loss: 0.03433385118842125
# #8 Loss: 0.028986603021621704
# #9 Loss: 0.024835558608174324
# #10 Loss: 0.02156173624098301
# #11 Loss: 0.018941795453429222
# #12 Loss: 0.016816964372992516
# #13 Loss: 0.01507264468818903
# #14 Loss: 0.013624816201627254
# #15 Loss: 0.012411035597324371
# #16 Loss: 0.011384191922843456
# #17 Loss: 0.010508296079933643
# #18 Loss: 0.00975551176816225
# #19 Loss: 0.009104082360863686
# #20 Loss: 0.008536800742149353
# #21 Loss: 0.008039954118430614
# #22 Loss: 0.007602455094456673
# #23 Loss: 0.007215335499495268
# #24 Loss: 0.006871234159916639
# #25 Loss: 0.00656408304348588
# #26 Loss: 0.006288836244493723
# #27 Loss: 0.006041282322257757
# #28 Loss: 0.005817874800413847
# #29 Loss: 0.005615629721432924
# ...
